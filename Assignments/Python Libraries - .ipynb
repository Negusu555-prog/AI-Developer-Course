# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

employees_df = pd.read_csv(r"C:\Users\Negus\OneDrive\שולחן העבודה\exam csv files\employees.csv")
jobs_df = pd.read_csv (r"C:\Users\Negus\OneDrive\שולחן העבודה\exam csv files\jobs.csv")
managers_df = pd.read_csv(r"C:\Users\Negus\OneDrive\שולחן העבודה\exam csv files\managers.csv")
positions_df = pd.read_csv(r"C:\Users\Negus\OneDrive\שולחן העבודה\exam csv files\positions.csv")

# %%
managers_df_copy = managers_df.copy()
employees_df_copy = employees_df.copy()
jobs_df_copy = jobs_df.copy()
positions_df_copy = positions_df.copy()
jobs_df_copy

# %%
is_duplicate = jobs_df_copy[jobs_df_copy.duplicated(subset = "job_title", keep = False)]
is_duplicate

# %%
# remove duplicates and modifies the original DataFrame
replace = {30:1, 31:2, 32:3, 33:4, 34:5, 35:6, 36:7}
# Set job_id as the index
jobs_df_copy.set_index('job_id', inplace=True)

# Drop the rows with job_ids specified in the dictionary keys
jobs_df_copy.drop(replace.keys(), axis=0, inplace=True)

# Display the modified DataFrame
jobs_df_copy

# %%
# Reset the index of the DataFrame
reset_index = jobs_df_copy.reset_index()

# Display the DataFrame with the reset index
reset_index

# %%
# Handle missing data in all datasets 
missing_data = managers_df_copy.isnull().sum()
count_rows = managers_df_copy.count()
is_above_five_percentage = missing_data / count_rows * 100
is_above_five_percentage
